# %% [markdown]
# # CBED and 4D-STEM performance
#
# Benchmark the public multislice APIs with representative array sizes.

# %%
from ptyrodactyl import multislice, types
import jax
import jax.numpy as jnp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
jax.config.update("jax_enable_x64", True)

# %%
key = jax.random.PRNGKey(0)

# %%
calibration = 0.1
num_modes = 200
beam_test_m = jax.random.normal(key, shape=(256, 256, num_modes), dtype=jnp.complex64)
beam_weights = jnp.arange(num_modes)
beam_weights /= jnp.sum(beam_weights)
slice_test_m = jax.random.normal(key, shape=(256, 256, 500), dtype=jnp.float64)

# %%
slices = types.create_potential_slices(slice_test_m, 1, calibration)
beams = types.create_probe_modes(beam_test_m, beam_weights, calibration)
microscope = types.create_microscope_config(
    voltage_kv=60.0, aperture_mrad=1.0
)

# %%
# %timeit multislice.cbed_image(slices, beams, microscope)

# %%
num_modes = 3
beam_weights = jnp.flip(1 + jnp.arange(num_modes))
beam_weights /= jnp.sum(beam_weights)
beam_test_small = jax.random.normal(key, shape=(128, 128, num_modes), dtype=jnp.complex64)
slice_test_small = jax.random.normal(key, shape=(128, 128, 200), dtype=jnp.float64)
slices_small = types.create_potential_slices(
    slice_test_small, 1, calibration
)
beams_small = types.create_probe_modes(
    beam_test_small, beam_weights, calibration
)

# %%
calib_ang = 0.2
x = jnp.arange(-4, 4, calib_ang)
y = jnp.arange(-4, 4, calib_ang)
xx, yy = jnp.meshgrid(x, y)
positions = jnp.asarray((xx.ravel(), yy.ravel())).T
detector = types.create_detector_config(
    real_space_calib_ang=calib_ang, scan_positions_px=positions
)

# %%
# %timeit multislice.stem_4d(slices_small, beams_small, microscope, detector)
