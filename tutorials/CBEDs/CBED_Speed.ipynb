# %%
import jax
import jax.numpy as jnp
from ptyrodactyl import simul, tools
# Out:
# W1203 16:58:51.420469 1780856 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.420533 1780851 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.420796 1780854 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.421939 1780855 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.423892 1780852 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.425701 1780853 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.425720 1780857 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.425870 1780850 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.454952 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.456334 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.457814 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.459297 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.460802 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.462307 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.463833 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1203 16:58:51.465345 1780247 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
jax.config.update("jax_enable_x64", True)

# %%
key = jax.random.PRNGKey(0)

# %%
calibration = 0.1
num_modes = 200
beam_test_m = jax.random.normal(key, shape=(256, 256, num_modes), dtype=jnp.complex64)
beam_weights = jnp.arange(num_modes)
beam_weights /= jnp.sum(beam_weights)
slice_test_m = jax.random.normal(key, shape=(256, 256, 500), dtype=jnp.float64)

# %%
slices = tools.make_potential_slices(slice_test_m, 1, calibration)
beams = tools.make_probe_modes(beam_test_m, beam_weights, calibration)

# %%
test_cbed = jax.jit(simul.cbed)

# %%
# %timeit test_cbed(slices, beams, jnp.asarray(60.0))
# Out:
# 6.78 s ± 22.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
num_modes = 3
beam_weights = jnp.flip(1 + jnp.arange(num_modes))
beam_weights /= jnp.sum(beam_weights)
beam_test_small = jax.random.normal(key, shape=(128, 128, num_modes), dtype=jnp.complex64)
slice_test_small = jax.random.normal(key, shape=(128, 128, 200), dtype=jnp.float64)
slices_small = tools.make_potential_slices(slice_test_small, 1, calibration)
beams_small = tools.make_probe_modes(beam_test_small, beam_weights, calibration)

# %%
calib_ang = 0.2
x = jnp.arange(-4, 4, calib_ang)
y = jnp.arange(-4, 4, calib_ang)
xx, yy = jnp.meshgrid(x, y)
positions = jnp.asarray((xx.ravel(), yy.ravel())).T

# %%
test_stem4d = jax.jit(simul.stem_4d)

# %%
help(simul.stem_4d)
# Out:
# Help on function stem_4d in module ptyrodactyl.simul.simulations:
#
# stem_4d(pot_slice: ptyrodactyl.tools.electron_types.PotentialSlices, beam: ptyrodactyl.tools.electron_types.ProbeModes, positions: jaxtyping.Num[Array, '#P 2'], voltage_kv: Union[int, float, jaxtyping.Num[Array, '']], calib_ang: Union[float, jaxtyping.Float[Array, '']]) -> ptyrodactyl.tools.electron_types.STEM4D
#     Simulate CBED patterns for multiple beam positions by shifting the beam and
#     running CBED simulations.
#
#     Parameters
#     ----------
#     pot_slice : PotentialSlices
#         The potential slice(s).
#     beam : ProbeModes
#         The electron beam mode(s).
#     positions : Num[Array, "#P 2"]
#         The (y, x) positions to shift the beam to.
#         With P being the number of positions.
#     voltage_kv : ScalarNumeric
#         The accelerating voltage in kilovolts.
#     calib_ang : ScalarFloat
#         The calibration in angstroms.
#
#     Returns
#     -------
#     STEM4D
#         Complete 4D-STEM dataset containing:
#         - Diffraction patterns for each scan position
#         - Real and Fourier space calibrations
#         - Scan positions in Angstroms
#         - Accelerating voltage
#
#     Notes
#     -----
#     Algorithm:
#     1. Shift beam to all specified positions
#     2. For each position, run CBED simulation
#     3. Return STEM4D PyTree with all data and calibrations

# %%
# %timeit test_stem4d(slices_small, beams_small, positions, jnp.asarray(60), calib_ang)
# Out:
# W1203 17:00:06.133520 1780247 bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.52GiB (rounded to 3775139328)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W1203 17:00:06.133667 1780247 bfc_allocator.cc:512] ************************____________________________________________________________________________
# E1203 17:00:06.133691 1780247 pjrt_stream_executor_client.cc:2085] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3.52GiB. [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# JaxRuntimeError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'test_stem4d(slices_small, beams_small, positions, jnp.asarray(60), calib_ang)')
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/IPython/core/magics/execution.py:1195, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1193 for index in range(0, 10):
#    1194     number = 10 ** index
# -> 1195     time_number = timer.timeit(number)
#    1196     if time_number >= 0.2:
#    1197         break
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
#     [... skipping hidden 5 frame]
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1378, in ExecuteReplicated.__call__(self, *args)
#    1376   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1377 else:
# -> 1378   results = self.xla_executable.execute_sharded(input_bufs)
#    1380 if dispatch.needs_check_special():
#    1381   out_arrays = results.disassemble_into_single_device_arrays()
#
# JaxRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3.52GiB.

# %%
test_stem4d_sharded = jax.jit(pte.stem_4D_sharded)

# %%
# %timeit test_stem4d_sharded(slices_small, beams_small, positions, jnp.asarray(60), calib_ang)
