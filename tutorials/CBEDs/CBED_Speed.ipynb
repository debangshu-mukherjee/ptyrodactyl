# %%
from ptyrodactyl import simul, tools
import jax
import jax.numpy as jnp
# Out:
# W1205 20:48:30.056221   47800 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.056432   47799 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.056856   47798 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.057318   47796 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.059080   47794 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.059613   47797 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.085171   47793 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.114349   47795 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.257188   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.258738   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.260290   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.261820   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.263724   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.265676   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.267201   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1205 20:48:30.268734   45578 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
jax.config.update("jax_enable_x64", True)

# %%
key = jax.random.PRNGKey(0)

# %%
calibration = 0.1
num_modes = 200
beam_test_m = jax.random.normal(key, shape=(256, 256, num_modes), dtype=jnp.complex64)
beam_weights = jnp.arange(num_modes)
beam_weights /= jnp.sum(beam_weights)
slice_test_m = jax.random.normal(key, shape=(256, 256, 500), dtype=jnp.float64)

# %%
slices = tools.make_potential_slices(slice_test_m, 1, calibration)
beams = tools.make_probe_modes(beam_test_m, beam_weights, calibration)

# %%
# %timeit simul.cbed(slices, beams, jnp.asarray(60.0))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'simul.cbed(slices, beams, jnp.asarray(60.0))')
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/IPython/core/magics/execution.py:1199, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1196         if time_number >= 0.2:
#    1197             break
# -> 1199 all_runs = timer.repeat(repeat, number)
#    1200 best = min(all_runs) / number
#    1201 worst = max(all_runs) / number
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/timeit.py:208, in Timer.repeat(self, repeat, number)
#     206 r = []
#     207 for i in range(repeat):
# --> 208     t = self.timeit(number)
#     209     r.append(t)
#     210 return r
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
#     [... skipping hidden 1 frame]
#
# File ~/ptyrodactyl/.venv/lib/python3.12/site-packages/jaxtyping/_decorator.py:449, in jaxtyped.<locals>.wrapped_fn_impl(args, kwargs, bound, memos)
#     446             raise TypeCheckError(msg) from e
#     448 # Actually call the function.
# --> 449 out = fn(*args, **kwargs)
#     451 if full_signature.return_annotation is not inspect.Signature.empty:
#     452     # Now type-check the return value. We need to include the
#     453     # parameters in the type-checking here in case there are any
#    (...)
#     464     # checking of the parameters. Unfortunately there doesn't seem
#     465     # to be a way around that, so c'est la vie.
#     466     kwargs[output_name] = out
#
# File ~/ptyrodactyl/src/ptyrodactyl/tools/electron_types.py:91, in CalibratedArray.tree_unflatten(cls, _aux_data, children)
#      80     """Flatten CalibratedArray for JAX pytree serialization."""
#      81     return (
#      82         (
#      83             self.data_array,
#    (...)
#      88         None,
#      89     )
# ---> 91 @classmethod
#      92 def tree_unflatten(
#      93     cls, _aux_data: None, children: Tuple[Any, ...]
#      94 ) -> "CalibratedArray":
#      95     """Reconstruct CalibratedArray from flattened pytree data."""
#      96     return cls(*children)
#
# KeyboardInterrupt:

# %%
num_modes = 3
beam_weights = jnp.flip(1 + jnp.arange(num_modes))
beam_weights /= jnp.sum(beam_weights)
beam_test_small = jax.random.normal(key, shape=(128, 128, num_modes), dtype=jnp.complex64)
slice_test_small = jax.random.normal(key, shape=(128, 128, 200), dtype=jnp.float64)
slices_small = tools.make_potential_slices(slice_test_small, 1, calibration)
beams_small = tools.make_probe_modes(beam_test_small, beam_weights, calibration)

# %%
calib_ang = 0.2
x = jnp.arange(-4, 4, calib_ang)
y = jnp.arange(-4, 4, calib_ang)
xx, yy = jnp.meshgrid(x, y)
positions = jnp.asarray((xx.ravel(), yy.ravel())).T

# %%
# %timeit simul.stem_4d(slices_small, beams_small, positions, jnp.asarray(60), calib_ang)
